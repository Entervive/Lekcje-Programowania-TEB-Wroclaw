# %% [markdown]
# # WIP(Work in progress)
# Importujemy na początku potrzebną biblotekę

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Wczytywanie danych na, których będziemy pracować

# %%
dane = pd.read_csv('dane.csv', sep=',')
dane
# Out:
#              WOJEWODZTWO                MARKA  LICZBA
# 0           DOLNOŚLĄSKIE           ALFA ROMEO      47
# 1           DOLNOŚLĄSKIE  ALLIED VEHICLES LTD       1
# 2           DOLNOŚLĄSKIE         ASTON MARTIN       2
# 3           DOLNOŚLĄSKIE                 AUDI     750
# 4           DOLNOŚLĄSKIE               AUSTIN       1
# ...                  ...                  ...     ...
# 1208  ZACHODNIOPOMORSKIE               TOYOTA     275
# 1209  ZACHODNIOPOMORSKIE               TOYOYA       1
# 1210  ZACHODNIOPOMORSKIE                  UAZ       1
# 1211  ZACHODNIOPOMORSKIE           VOLKSWAGEN     556
# 1212  ZACHODNIOPOMORSKIE                VOLVO     187
#
# [1213 rows x 3 columns]

# %% [markdown]
# Selekcjonowanie danych dla województwa dolnoślaskiego

# %%
dane[dane['WOJEWODZTWO'] == "DOLNOŚLĄSKIE"]
